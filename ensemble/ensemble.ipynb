# %%
import numpy as np
import pandas as pd


tfidf_lr = pd.read_csv('result/prob/prob_lr_baseline.csv') # PL score 0.9829
svm_baseline = pd.read_csv('result/prob/prob_svm_baseline.csv') # 0.9811
svm_char_ngram13 = pd.read_csv('result/prob/prob_svm_char_ngram13.csv') # 0.9811
svm_word_ngram12 = pd.read_csv('result/prob/prob_svm_word_ngram12.csv')
lr_char_ngram13 = pd.read_csv('result/prob/prob_lr_char_ngram13.csv')
lr_word_ngram12 = pd.read_csv('result/prob/prob_lr_baseline.csv')
enhance_lr_word_ngram12 = pd.read_csv('result/prob/prob_enhance_lr_baseline.csv')
bigru_split = pd.read_csv('result/prob/prob_bigru_split.csv') # 0.74
bigru_split = bigru_split.groupby(bigru_split['id']).mean()
long_textcnn = pd.read_csv('result/prob/prob_long_textcnn_test.csv') # 0.73
mlp = pd.read_csv('result/prob/prob_mlp_top1000.csv') # 0.73
#mlp = pd.read_csv('result/prob/prob_long_textcnn_test.csv') # 0.73

# %%
textcnn_char = pd.read_csv('result/prob/prob_textcnn_char.csv')
textcnn_char = textcnn_char.drop(['id'],axis = 1)

# %%
nb = pd.read_csv('result/prob/prob_nb_baseline.csv')
nb = nb.drop(['id'],axis = 1)

# %%
bigru_split = pd.read_csv('result/prob/prob_bigru_split.csv') # 0.74
bigru_split = bigru_split.groupby(bigru_split['id']).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-397cdeab6029> in <module>()
# ----> 1 bigru_split = pd.read_csv('result/prob/prob_bigru_split.csv') # 0.74
#       2 bigru_split = bigru_split.groupby(bigru_split['id']).mean()
#
# NameError: name 'pd' is not defined

# %%
bigru_split.head()
# Out:
#     class_prob_1  class_prob_2  class_prob_3  class_prob_4  class_prob_5  \
# id
# 0       0.009295  1.204781e-03  1.776744e-04      0.000150  9.800779e-01
# 1       0.005287  3.073233e-06  1.767784e-06      0.983985  3.448950e-05
# 2       0.022193  4.719931e-02  2.193699e-02      0.000235  1.397110e-03
# 3       0.000058  5.602849e-10  3.839689e-10      0.999857  2.698765e-08
# 4       0.118646  7.650657e-04  5.667138e-04      0.002930  7.854701e-01
#
#     class_prob_6  class_prob_7  class_prob_8  class_prob_9  class_prob_10  \
# id
# 0       0.000292      0.001033      0.000199  2.833322e-07   3.468543e-03
# 1       0.000179      0.000272      0.002595  3.787335e-05   4.223678e-04
# 2       0.001215      0.000983      0.091145  3.039799e-04   7.732936e-02
# 3       0.000004      0.000005      0.000019  3.158696e-07   3.480805e-07
# 4       0.002408      0.007981      0.003926  4.159140e-05   1.911178e-02
#
# ...

# %%
bigru_split.head()
# Out:
#     class_prob_1  class_prob_2  class_prob_3  class_prob_4  class_prob_5  \
# id
# 0       0.009295  1.204781e-03  1.776744e-04      0.000150  9.800779e-01
# 1       0.005287  3.073233e-06  1.767784e-06      0.983985  3.448950e-05
# 2       0.022193  4.719931e-02  2.193699e-02      0.000235  1.397110e-03
# 3       0.000058  5.602849e-10  3.839689e-10      0.999857  2.698765e-08
# 4       0.118646  7.650657e-04  5.667138e-04      0.002930  7.854701e-01
#
#     class_prob_6  class_prob_7  class_prob_8  class_prob_9  class_prob_10  \
# id
# 0       0.000292      0.001033      0.000199  2.833322e-07   3.468543e-03
# 1       0.000179      0.000272      0.002595  3.787335e-05   4.223678e-04
# 2       0.001215      0.000983      0.091145  3.039799e-04   7.732936e-02
# 3       0.000004      0.000005      0.000019  3.158696e-07   3.480805e-07
# 4       0.002408      0.007981      0.003926  4.159140e-05   1.911178e-02
#
# ...

# %%
long_textcnn = long_textcnn.drop(['id'],axis = 1)

# %%
svm_char_ngram13 = svm_char_ngram13.drop(['id'],axis = 1)
svm_word_ngram12 = svm_word_ngram12.drop(['id'],axis = 1)
lr_char_ngram13 = lr_char_ngram13.drop(['id'],axis = 1)
lr_word_ngram12 = lr_word_ngram12.drop(['id'],axis = 1)
enhance_lr_word_ngram12 = enhance_lr_word_ngram12.drop(['id'],axis = 1)
mlp = mlp.drop(['id'],axis = 1)

# %%
ensemble = bigru_split + long_textcnn + svm_char_ngram13 + svm_word_ngram12 + lr_char_ngram13 + enhance_lr_word_ngram12 + textcnn_char + mlp

# %%
#ensemble = svm_char_ngram13 + svm_word_ngram12 + lr_char_ngram13 + lr_word_ngram12 + nb

# %%
ensemble.head()
# Out:
#     class_prob_1  class_prob_2  class_prob_3  class_prob_4  class_prob_5  \
# id
# 0       0.427428      0.069048      0.021379      0.068773      6.162765
# 1       0.167387      0.028056      0.669175      5.429508      0.026169
# 2       0.278433      0.118346      0.500127      0.071295      0.098947
# 3       0.040351      0.008704      0.035225      6.603267      0.012457
# 4       0.451345      0.025238      0.041995      0.435259      3.430273
#
#     class_prob_6  class_prob_7  class_prob_8  class_prob_9  class_prob_10  \
# id
# 0       0.051053      0.033066      0.056220      0.041429       0.054475
# 1       0.292052      0.042402      0.052817      0.028276       0.058401
# 2       0.037242      0.138394      0.821636      0.041050       0.156228
# 3       0.103462      0.012544      0.032746      0.012717       0.019969
# 4       0.030690      0.312036      0.068104      0.341708       0.251482
#
# ...

# %%
# ensemble = split_textcnn.groupby(split_textcnn['id']).mean()

ensemble = np.array(ensemble)

# %%
ensemble = np.array(ensemble.drop(['id'],axis=1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-182dca4808f1> in <module>()
# ----> 1 ensemble = np.array(ensemble.drop(['id'],axis=1))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
ensemble[:5]
# Out:
# array([[0.42742786, 0.06904796, 0.02137931, 0.06877324, 6.16276476,
#         0.05105339, 0.03306643, 0.05622025, 0.04142904, 0.05447511,
#         0.06135531, 0.03791283, 0.0375413 , 0.33588746, 0.08118306,
#         0.36676785, 0.02184993, 0.01982666, 0.05203829],
#        [0.16738725, 0.02805565, 0.6691745 , 5.42950812, 0.02616874,
#         0.29205183, 0.04240157, 0.05281746, 0.02827581, 0.05840137,
#         0.03194674, 0.43974434, 0.04090083, 0.09458074, 0.11959249,
#         0.04059538, 0.02404438, 0.28481337, 0.12953954],
#        [0.27843345, 0.11834616, 0.50012679, 0.07129492, 0.09894706,
#         0.0372423 , 0.13839447, 0.82163592, 0.04105046, 0.15622754,
#         0.16257951, 0.42150666, 3.49986248, 0.97679   , 0.14727475,
#         0.04104165, 0.12326147, 0.05277102, 0.31321328],
#        [0.04035062, 0.00870436, 0.035225  , 6.60326731, 0.01245696,
#         0.10346194, 0.01254413, 0.03274606, 0.01271703, 0.01996869,
# ...

# %%
all_predictions=np.argmax(ensemble,axis=1)

# %%
all_predictions = all_predictions+1

# %%
all_predictions[:5]
# Out:
# array([ 5,  4, 13,  4,  5])

# %%
test_id = pd.read_csv("data/test_set.csv")

# %%
test_pred=pd.DataFrame(all_predictions)
test_pred.columns=["class"]
test_pred["class"]=(test_pred["class"]).astype(int)
print(test_pred.shape)
print(test_id.shape)
test_pred["id"]=list(test_id["id"])
test_pred[["id","class"]].to_csv('submit/en_svm_enhancelr_spplitbigru_longtextcnn+textcnnchar+mlp.csv',index=None)
# Out:
# (102277, 1)
# (102277, 3)

# %%
test_pred[:5]
# Out:
#    class  id
# 0      5   0
# 1      4   1
# 2     13   2
# 3      4   3
# 4      5   4
